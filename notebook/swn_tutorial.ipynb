# %%
from slm.swn import Swn

# %%
# %matplotlib inline

# %%
swno = Swn(swn_filename='../swn/DATA0025.SWN')

# %%
swno.plot(figsize=(20, 10))
# Out:
# <class 'matplotlib.axes._subplots.AxesSubplot'>
# <AxesSubplot:xlabel='date_and_time'>

# %% [markdown]
# ![Decibel examples](images/decibel_examples.jpg)
#
# Source https://en.wikipedia.org/wiki/Decibel#Examples
